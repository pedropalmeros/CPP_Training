# %% [markdown]
# # Static member functions
#
# Just as the static variables, the memeber functions are designed to be part of the class, not the object. Hence they can be called without having a object of the class.

# %% [markdown]
# The static member functions do not have the `this` pointer. Hence, they cannot be declared as `const`
#
# the static member functions cannot have access to any memeber variable that is not static.
